# %%
firstname = 'kiran'
lastname = 'reddy'

fullname = f'{firstname} {lastname}'
print(fullname)
# Out:
# kiran reddy

# %%
print(fullname.title())
# Out:
# Kiran Reddy

# %%
message = f'keep up the good work,{fullname.title()}'
print(message)
# Out:
# keep up the good work,Kiran Reddy

# %%
print('favourite_prog_lang:pythonc++javacswiftjavascript')
# Out:
# favourite_prog_lang:pythonc++javacswiftjavascript

# %%
print('favourite_prog_lang:\npython\nc++\njava\nc\nswift\njavascript')
# Out:
# favourite_prog_lang:
# python
# c++
# java
# c
# swift
# javascript

# %%
print('favourite_prog_lang:\n\tpython\n\tc++\n\tjava\n\tc\n\tswift\n\tjavascript')
# Out:
# favourite_prog_lang:
# 	python
# 	c++
# 	java
# 	c
# 	swift
# 	javascript

# %%
name = " python"
print(name)
# Out:
#  python

# %%
name2 = "python "
print(name2)
# Out:
# python

# %%
name.lstrip()
# Out:
# 'python'

# %%
name2.rstrip()
# Out:
# 'python'

# %%
name3 = " python "
print(name3)
# Out:
#  python

# %%
name3.strip()
# Out:
# 'python'

# %%
import this
