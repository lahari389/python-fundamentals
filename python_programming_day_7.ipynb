# %%
alien = {'color':'green','points':'5',}
print(alien)
# Out:
# {'color': 'green', 'points': '5'}

# %%
type(alien)
# Out:
# dict

# %%
alien['start_position'] = "level1"
print(alien)
# Out:
# {'color': 'green', 'points': '5', 'start_position': 'level1'}

# %%
alien['color']
# Out:
# 'green'

# %%
alien['points']
# Out:
# '5'

# %%
alien['start_position']
# Out:
# 'level1'

# %%
print(alien)
# Out:
# {'color': 'green', 'points': '5', 'start_position': 'level1'}

# %%
alien['end_position'] = "level100000"
print(alien)
# Out:
# {'color': 'green', 'points': '5', 'start_position': 'level1', 'end_position': 'level100000'}

# %%
alien['end_position']
# Out:
# 'level100000'

# %%
# creating a new instagram account

# %%
user_account = {'username':'aesthetic01','username':'music','dob':'25-05-2020','password':'0987654321'}
print(user_account)
# Out:
# {'username': 'music', 'dob': '25-05-2020', 'password': '0987654321'}

# %%
del user_account['username']
print(user_account)
# Out:
# {'dob': '25-05-2020', 'password': '0987654321'}

# %%
print(alien)
# Out:
# {'color': 'green', 'points': '5', 'start_position': 'level1', 'end_position': 'level100000'}

# %%
for tempvar1,tempvar2 in mainvar.items():
print(tempvar1)
print(tempvar2)

# %%
print(alien)
# Out:
# {'color': 'green', 'points': '5', 'start_position': 'level1', 'end_position': 'level100000'}

# %%
for k,v in alien.items():
    print(k)
    print(v)
# Out:
# color
# green
# points
# 5
# start_position
# level1
# end_position
# level100000

# %%
for k,v in alien.items():
    print(f"key:{k}")
    print(f"value:{v}")
# Out:
# key:color
# value:green
# key:points
# value:5
# key:start_position
# value:level1
# key:end_position
# value:level100000

# %%
for k,v in alien.items():
    print(f"key:{k}")
    print(f"value:{v}\n")
# Out:
# key:color
# value:green
#
# key:points
# value:5
#
# key:start_position
# value:level1
#
# key:end_position
# value:level100000
