# %%
a=2
b=3
c = a+b
print(c)
# Out:
# 5

# %%
firstname="lahari"
print(firstname)
# Out:
# lahari

# %%
first_name='lahari'
print(first_name)
# Out:
# lahari

# %%
name1='lahari'
print(name1)
# Out:
# lahari

# %%
name='lahari'
print(name)
# Out:
# lahari

# %%
name2="lahari"
print(name2)
# Out:
# lahari

# %%
type(name)
# Out:
# str

# %%
type(name2)
# Out:
# str

# %%
fullname='lahari karri'
print(fullname)
# Out:
# lahari karri

# %%
print(fullname.title())
# Out:
# Lahari Karri

# %%
print(fullname.upper())
# Out:
# LAHARI KARRI

# %%
print(fullname.lower())
# Out:
# lahari karri
