# %%
num = 1
num2 = 4

num3 = num+num2
print(num3)
# Out:
# 5

# %%
type(num)
# Out:
# int

# %%
x = 0.1
print(x)
# Out:
# 0.1

# %%
type(x)
# Out:
# float

# %%
# list datatype

# %%
students = ['vicky','abdul','shree','anwar','murali']
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali']

# %%
print(students[2])
# Out:
# shree

# %%
print(students[2].title())
# Out:
# Shree

# %%
# adding an element to list..

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali']

# %%
students.append('varun')
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali', 'varun', 'varun']

# %%
y = students.pop()
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali', 'varun']

# %%
students.append('praneeth')
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali', 'varun', 'praneeth']

# %%
students.insert(2,'divya')
print(students)
# Out:
# ['vicky', 'abdul', 'divya', 'shree', 'anwar', 'murali', 'varun', 'praneeth']

# %%
# modifying elements to the list...

# %%
students[2] = 'dinesh'
print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murali', 'varun', 'praneeth']

# %%
# deleting elements in the list..

# %%
y = students.pop()
print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murali', 'varun']

# %%
print(y)
# Out:
# praneeth

# %%
a = students.pop(0)
print(students)
# Out:
# ['abdul', 'dinesh', 'shree', 'anwar', 'murali', 'varun']

# %%
print(a)
# Out:
# vicky

# %%
del students[1]
print(students)
# Out:
# ['abdul', 'shree', 'anwar', 'murali', 'varun']
