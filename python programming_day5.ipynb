# %%
cars = ['kia','audi','maruthi','hyundai','benz','volkswagen','suzuki','bmw']

print(cars)
# Out:
# ['kia', 'audi', 'maruthi', 'hyundai', 'benz', 'volkswagen', 'suzuki', 'bmw']

# %%
# i want to organize the listin the alphabetical order...
# a-z ( order i wantv to maintain..)

# %%
print(sorted(cars))
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'maruthi', 'suzuki', 'volkswagen']

# %%
print(cars)
# Out:
# ['kia', 'audi', 'maruthi', 'hyundai', 'benz', 'volkswagen', 'suzuki', 'bmw']

# %%
cars.sort()
print(cars)
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'maruthi', 'suzuki', 'volkswagen']

# %%
print(cars)
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'maruthi', 'suzuki', 'volkswagen']

# %%
len(cars)
# Out:
# 8

# %%
cars.reverse()
print(cars)
# Out:
# ['volkswagen', 'suzuki', 'maruthi', 'kia', 'hyundai', 'bmw', 'benz', 'audi']

# %%
[start_value:last_value:steps_count]

# %%
students=('divya','harika','naveen','hafsa','karthik','vicky')
print(students)
# Out:
# ('divya', 'harika', 'naveen', 'hafsa', 'karthik', 'vicky')

# %%
print(students[0:1])
# Out:
# ('divya',)

# %%
print(students[0:2])
# Out:
# ('divya', 'harika')

# %%
print(students[2:4])
# Out:
# ('naveen', 'hafsa')

# %%
print(students[0:4:2])
# Out:
# ('divya', 'naveen')
